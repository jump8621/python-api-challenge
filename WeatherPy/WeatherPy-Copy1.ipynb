# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 630

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# # Dependencies
# import requests
# from config import api_key
# import time

# url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# # Store a search term
# query = "obama"

# # Search for articles published between a begin and end date
# begin_date = "20160101"
# end_date = "20160130"
# BONUS: How would we get 30 results? 
# HINT: Look up the page query param

# # Empty list for articles
# articles_list = []

# # loop through pages 0-2
# for page in range(0, 3):
#     query_url = f"{url}api-key={api_key}&q={query}&begin_date={begin_date}&end_date={end_date}"
#     # create query with page number
#     query_url = f"{query_url}&page={str(page)}"
#     articles = requests.get(query_url).json()
    
#     # Add a one second interval between queries to stay within API query limits
#     time.sleep(1)
#     # loop through the response and append each article to the list
#     for article in articles["response"]["docs"]:
#         articles_list.append(article)
# for article in articles_list:
#     print(article['snippet'])
#     print('---------------------------')

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units={units}&q="

search_data = []
city_List = []
country_List = []
# humidity = []
# max_temp = []
# cloud = []
# date = []
# lat = []
# long = []
# wind_speed = []


searchCnt = 0
print("Begin API Call to OpenWeather Database ")
print("---------------------------------------")

for city in cities:
    try:
        print(f"Processing record {searchCnt} for the city: {city}")
        searchCnt += 1
        response = requests.get(query_url + city)
        wdata = response.json()
        countryy = wdata['sys']['country']
        searchCityID = wdata['id']
        search_data.append(wdata)
        city_List.append(city)
        country_List.append(countryy)   
        print(f"Record found for city: {city} with city id: {searchCityID}")
    except Exception as ex:
        print(f"No weather record found for city: {city}")
        time.sleep(4)
        pass


print("---------------------------------------")
print("Processing Complete")


#         humidity = wdata['main']['humidity']
#         max_temp = wdata['main']['temp_max']
#         cloud = wdata['clouds']['all']
#         date = wdata['dt']
#         lat = wdata['coord']['lat']
#         long = wdata['coord']['lon']
#         wind_speed = wdata['wind']['speed']
# humidity_list.append(humidity)
#         max_temp.append(max_temp)
#         cloud.append(cloud)
#         date.append(date)
#         lat.append(lat)
#         long.append(long)
#         wind_speed.append(wind_speed)
# Out:
# Begin API Call to OpenWeather Database
# ---------------------------------------
# Processing record 0 for the city: goderich
# Record found for city: goderich with city id: 5962442
# Processing record 1 for the city: jamestown
# Record found for city: jamestown with city id: 5122534
# Processing record 2 for the city: souillac
# Record found for city: souillac with city id: 933995
# Processing record 3 for the city: saint-philippe
# Record found for city: saint-philippe with city id: 935215
# Processing record 4 for the city: taolanaro
# No weather record found for city: taolanaro
# Processing record 5 for the city: cabra
# Record found for city: cabra with city id: 2520645
# Processing record 6 for the city: amderma
# No weather record found for city: amderma
# Processing record 7 for the city: saskylakh
# Record found for city: saskylakh with city id: 2017155
# Processing record 8 for the city: tuatapere
# Record found for city: tuatapere with city id: 2180815
# ...

# %%
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | butaritari
# Processing Record 2 of Set 1 | yerbogachen
# Processing Record 3 of Set 1 | cape town
# Processing Record 4 of Set 1 | touba
# Processing Record 5 of Set 1 | jamestown
# Processing Record 6 of Set 1 | rio grande
# Processing Record 7 of Set 1 | ibra
# Processing Record 8 of Set 1 | port elizabeth
# Processing Record 9 of Set 1 | tuktoyaktuk
# Processing Record 10 of Set 1 | avarua
# Processing Record 11 of Set 1 | nemuro
# Processing Record 12 of Set 1 | morgan city
# Processing Record 13 of Set 1 | hobart
# Processing Record 14 of Set 1 | kawalu
# Processing Record 15 of Set 1 | hami
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | katsuura
# Processing Record 18 of Set 1 | hjallerup
# Processing Record 19 of Set 1 | punta arenas
# Processing Record 20 of Set 1 | bengkulu
# Processing Record 21 of Set 1 | victoria
# ...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
lat_info =  [data.get("coord").get("lat") for data in search_data]
long_info = [data.get("coord").get("lon") for data in search_data]
temp_info = [data.get("main").get("temp") for data in search_data]
humid_info = [data.get("main").get("humidity") for data in search_data]
cloud_info =[data.get("clouds").get("all") for data in search_data]
wind_info = [data.get("wind").get("speed") for data in search_data]
date_info = [data.get("dt") for data in search_data]

# %%
weather_info_df = pd.DataFrame({"City Name" : city_List,
                            "Lat" : lat_info,
                            "Lng" : long_info,
                            "Max Temp" : temp_info,
                            "Humidity" : humid_info,
                            "Cloudiness" : cloud_info,
                            "Wind Speed" : wind_info,
                            "Country" : country_List,
                             "Date" : date_info})
weather_info_df.head(6)
# Out:
#         City Name    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        goderich  43.75  -81.72     47.98        87         100       23.67
# 1       jamestown  42.10  -79.24     67.44        60          75       12.75
# 2        souillac -20.52   57.52     73.40        73          40       11.41
# 3  saint-philippe -21.36   55.77     68.56        73          20        5.82
# 4           cabra  37.47   -4.44     57.99        81           0        0.29
# 5       saskylakh  71.92  114.08     17.02        96         100        8.23
#
#   Country        Date
# 0      CA  1603504213
# 1      US  1603504426
# 2      MU  1603504369
# 3      RE  1603504374
# 4      ES  1603504384
# 5      RU  1603504395

# %%
weather_info_df.to_csv('../output_data/cities.csv')

# %%
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   butaritari   3.07  172.79     83.32        74          84       10.42
# 1  yerbogachen  61.28  108.01     79.52        58          20        7.70
# 2    cape town -33.93   18.42     73.00        77          27        4.70
# 3        touba   8.28   -7.68     79.97        75          82        3.58
# 4    jamestown  42.10  -79.24     64.00        88           1        6.93
#
#   Country        Date
# 0      KI  1593605283
# 1      RU  1593605121
# 2      ZA  1593605039
# 3      CI  1593605284
# 4      US  1593605284

# %%
weather_info_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  578.000000  578.000000  578.000000  578.000000  578.000000  578.000000
# mean    19.703374   18.429723   59.553927   74.430796   54.356401    8.001107
# std     33.560968   93.336355   19.717634   20.026314   39.869862    5.987892
# min    -54.800000 -175.200000   -4.000000    1.000000    0.000000    0.290000
# 25%     -8.605000  -63.212500   46.127500   64.000000    8.250000    3.360000
# 50%     23.510000   23.205000   63.700000   79.000000   68.000000    6.770000
# 75%     47.657500  102.267500   76.267500   90.000000   93.000000   10.767500
# max     78.220000  179.320000   95.000000  100.000000  100.000000   37.180000
#
#                Date
# count  5.780000e+02
# mean   1.603505e+09
# std    1.472787e+02
# min    1.603504e+09
# 25%    1.603505e+09
# 50%    1.603505e+09
# 75%    1.603505e+09
# max    1.603505e+09

# %%
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  599.000000  599.000000  599.000000  599.000000  599.000000  599.000000
# mean    19.877028   19.568998   69.794808   69.353923   51.569282    7.979416
# std     33.262944   91.418472   15.678452   22.704698   35.405602    5.660694
# min    -54.800000 -179.170000   12.200000    7.000000    0.000000    0.360000
# 25%     -8.540000  -61.210000   59.000000   55.000000   20.000000    3.620000
# 50%     24.370000   24.670000   73.110000   75.000000   59.000000    6.730000
# 75%     46.585000  102.255000   80.600000   87.000000   85.000000   11.050000
# max     78.220000  179.320000  116.600000  100.000000  100.000000   42.500000
#
#                Date
# count  5.990000e+02
# mean   1.593605e+09
# std    5.738815e+01
# min    1.593605e+09
# 25%    1.593605e+09
# 50%    1.593605e+09
# 75%    1.593605e+09
# max    1.593605e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
label = weather_info_df ['Humidity'].idxmax()
print(label)
label_df = weather_info_df.iloc[56]
label_df

weather_info_df['Humidity'].value_counts()
humidty_df = weather_info_df.where(weather_info_df['Humidity']>99.9, other=np.nan)
humidty_df.dropna()
# weather_info_df.tail(20)
# Out:
# 56
#               City Name    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 56        mar del plata -38.00  -57.56     56.97     100.0        75.0
# 71              chapais  49.78  -74.85     33.80     100.0        90.0
# 89         norman wells  65.28 -126.83     28.40     100.0        75.0
# 188         worthington  40.09  -83.02     62.73     100.0        90.0
# 212              anadyr  64.75  177.48     24.80     100.0        75.0
# 260          hambantota   6.12   81.12     77.00     100.0        20.0
# 272               ancud -41.87  -73.82     46.80     100.0        90.0
# 302     muntenii de jos  46.62   27.77     45.70     100.0       100.0
# 310        martinsville  36.69  -79.87     61.70     100.0         1.0
# 316            chambery  45.57    5.93     50.22     100.0        90.0
# 339            sinzheim  48.76    8.17     56.10     100.0        36.0
# 341             cayenne   4.93  -52.33     77.00     100.0        20.0
# ...

# %%
cleaned_weather_df = weather_info_df.drop(humidty_df.index[[56, 71, 89, 188, 212, 260, 272, 302, 310, 316, 339, 341, 377, 392, 397, 451, 490, 500, 532, 550, 556, 577]], inplace = False)
# '71', '89', '188', '212', '260', '272', '302', '310', '316', '339', '341', '377', '392', '397', '451', '490', '500', '532', '550', '556', '577'

# %%
cleaned_weather_df.tail(25)
# Out:
#                     City Name    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 551            port shepstone -30.74   30.45     68.74        89         100
# 552                  kirakira -10.45  161.92     83.17        78          78
# 553                 hermiston  45.84 -119.29     47.32        57          90
# 554                    mahina -17.51 -149.49     82.20        69          75
# 555                 dalbandin  28.89   64.41     49.28        47           0
# 557                 toshkivka  48.78   38.58     54.73        93         100
# 558             mount gambier -37.83  140.77     55.40        62          90
# 559                    makaha  21.47 -158.22     80.44        88          75
# 560  sao jose da coroa grande  -8.90  -35.15     76.30        86           7
# 561                    guadix  37.30   -3.14     45.88        81           0
# 562                  marchena  37.33   -5.42     57.36        93           0
# ...

# %%
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  550.000000  550.000000  550.000000  550.000000  550.000000  550.000000
# mean    19.973545   17.124400   58.331400   67.890909   52.141818    8.544800
# std     33.284840   91.595451   25.795297   20.864881   35.766469    6.078869
# min    -54.800000 -179.170000  -11.340000    9.000000    0.000000    0.160000
# 25%     -8.077500  -64.627500   42.800000   55.000000   20.000000    4.525000
# 50%     23.630000   19.635000   64.940000   72.000000   57.000000    7.325000
# 75%     48.672500   97.350000   78.800000   83.000000   86.750000   11.410000
# max     78.220000  179.320000  102.200000  100.000000  100.000000   46.080000
#
#                Date
# count  5.500000e+02
# mean   1.585764e+09
# std    5.539674e+01
# min    1.585764e+09
# 25%    1.585764e+09
# 50%    1.585764e+09
# 75%    1.585764e+09
# max    1.585764e+09

# %%
#  Get the indices of cities that have humidity over 100%.
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   butaritari   3.07  172.79     83.32        74          84       10.42
# 1  yerbogachen  61.28  108.01     79.52        58          20        7.70
# 2    cape town -33.93   18.42     73.00        77          27        4.70
# 3        touba   8.28   -7.68     79.97        75          82        3.58
# 4    jamestown  42.10  -79.24     64.00        88           1        6.93
#
#   Country        Date
# 0      KI  1593605283
# 1      RU  1593605121
# 2      ZA  1593605039
# 3      CI  1593605284
# 4      US  1593605284

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# cleaned_weather_df.plot.scatter(x='Lat', y='Max Temp')
Latitude = cleaned_weather_df['Lat']
Max_Temp = cleaned_weather_df['Max Temp']
lt_x_values = Latitude
lt_y_values = Max_Temp


plt.scatter(lt_x_values, lt_y_values, edgecolors='black', color='turquoise')
plt.title('City Latitude vs. Max Temperature',  fontweight='bold')
plt.ylabel('Max Temperature (F)')
plt.xlabel('Latitude')
plt.grid()
plt.show
plt.close
plt.savefig('tempvslat.png')

# %%
# The above plot is a pyplot scatter plot.  The code pulls the Latitude and the Max Temperature for each city on the date
# the data was pulled and then plots the coordinates on the graph.
# This allows for easier visual, and quick analysis on whether a cities latitude(distance from the equator) impacts its max
# temperature.
# While the temps above 40 seem to be be semi uniform; only the Northen Hemisphere has max temperatures below 40 degrees F.
# on the date pulled

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
Latitude = cleaned_weather_df['Lat']
Humidity = cleaned_weather_df['Humidity']
hum_x_values = Latitude
hum_y_values = Humidity


plt.scatter(hum_x_values, hum_y_values, edgecolors='black', color='turquoise')
plt.title('City Latitude vs. Humidity',  fontweight='bold')
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')
plt.grid()
plt.show
plt.close
plt.savefig('humidityvslat.png')

# %%
# The above code pulls the cities Latitude and humidity percent at the time the data was pulled and plots on a scatter plot graph.
# This visual, seems to indicate that there is not a correlation between humidity and location.  Though at close examination there
# seems to be a slightly more dots on the right side of the graph(the Northern Hemishphere).

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
Latitude = cleaned_weather_df['Lat']
Cloudiness = cleaned_weather_df['Cloudiness']
cloud_x_values = Latitude
cloud_y_values = Cloudiness


plt.scatter(cloud_x_values, cloud_y_values, edgecolors='blue', color='turquoise')
plt.title('City Latitude vs. Cloudiness',  fontweight='bold')
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')
plt.grid()
plt.show
plt.close
plt.savefig('cloudsvslat.png')

# %%
# The code is the same as the last two plots except for pulling the cloudiness and the city latitude
# Analyzing this graph the code seems to have shown that there is no correlation between city latitude and cloudiness.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
Latitude = cleaned_weather_df['Lat']
Wind = cleaned_weather_df['Wind Speed']
wind_x_values = Latitude
wind_y_values = Wind


plt.scatter(wind_x_values, wind_y_values, edgecolors='blue', color='turquoise')
plt.title('City Latitude vs. Wind Speed',  fontweight='bold')
plt.ylabel('Wind Speed (mph)')
plt.xlabel('Latitude')
plt.grid()
plt.show
plt.close
plt.savefig('windvslat.png')

# %%
# Here the code picked wind speed to compare to the latitude.
# The graph seems to show only a slight correlation to the Northern Hemisphere;
# Any wind speed above 25 mph is only found in the Northern Hemisphere.

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Northern Hemisphere (greater than or equal to 0 degrees latitude)
north_Latitude_df = cleaned_weather_df.loc[cleaned_weather_df['Lat']>=0]
North_Latitude = north_Latitude_df['Lat']
Max_Temp = north_Latitude_df['Max Temp']
x_values = North_Latitude
y_values = Max_Temp
                                                                                             
# x_values = 'Latitude'
# y_values = 'Max Temperature'
# line_eq = 'y =
# (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(x_values,y_values,)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(10,20),fontsize=15,color="red")
plt.title('Northern Hemisphere - Latitude vs. Max Temperature', fontsize=15, fontweight='bold')
plt.ylabel('Max Temperature (F)')
plt.xlabel('Latitude')
print(f"The r-value is: {rvalue}")
print("R-squared: %f" % rvalue**2)
plt.show
plt.close
plt.savefig('N_tempvslat_reg.png')
# Out:
# The r-value is: -0.8961189000098607
# R-squared: 0.803029

# %%
# Out:
# The r-value is: 0.46937863826630627

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Southern Hemisphere (less than 0 degrees latitude)
s_Latitude_df = cleaned_weather_df.loc[cleaned_weather_df['Lat']<0]
S_Latitude = s_Latitude_df['Lat']
Max_Temp = s_Latitude_df['Max Temp']
x_values = S_Latitude
y_values = Max_Temp


(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(x_values,y_values,)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,90),fontsize=15,color="red")
plt.title('Southern Hemisphere - Latitude vs. Max Temperature', fontsize=15, fontweight='bold')
plt.ylabel('Max Temperature (F)')
plt.xlabel('Latitude')
print(f"The r-value is: {rvalue}")
print("R-squared: %f" % rvalue**2)
plt.show
plt.close
plt.savefig('S_tempvslat_reg.png')
# Out:
# The r-value is: 0.6804663605135727
# R-squared: 0.463034

# %%
# Out:
# The r-value is: 0.6082708688906918

# %%
#Northern Hemisphere (greater than or equal to 0 degrees latitude)
north_Latitude_df = cleaned_weather_df.loc[cleaned_weather_df['Lat']>=0]
North_Latitude = north_Latitude_df['Lat']
Max_Temp = north_Latitude_df['Max Temp']
N_x_values = North_Latitude
N_y_values = Max_Temp
(slope, intercept, rvalue, pvalue, stderr) = linregress(N_x_values, N_y_values)
regress_values = N_x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(N_x_values,N_y_values,)
plt.plot(N_x_values,regress_values,"r-")
plt.annotate(line_eq,(10,20),fontsize=15,color="red")
plt.title('Northern Hemisphere - Latitude vs. Max Temperature', fontsize=15, fontweight='bold')
plt.ylabel('Max Temperature (F)')
plt.xlabel('Latitude')
print(f"The r-value is: {rvalue}")
print("R-squared: %f" % rvalue**2)

s_Latitude_df = cleaned_weather_df.loc[cleaned_weather_df['Lat']<0]
S_Latitude = s_Latitude_df['Lat']
Max_Temp = s_Latitude_df['Max Temp']
x_values = S_Latitude
y_values = Max_Temp

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(x_values,y_values,)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,90),fontsize=15,color="red")
plt.title('Southern Hemisphere - Latitude vs. Max Temperature', fontsize=15, fontweight='bold')
plt.ylabel('Max Temperature (F)')
plt.xlabel('Latitude')
print(f"The r-value is: {rvalue}")
print("R-squared: %f" % rvalue**2)
plt.show
plt.close
# Out:
# The r-value is: -0.8961189000098607
# R-squared: 0.803029
# The r-value is: 0.6804663605135727
# R-squared: 0.463034
# <function matplotlib.pyplot.close(fig=None)>

# %%
# The two graphs plotting the max temperature vs latitude in the two different hemispheres - The linear regression is modeling
# the prediction line and showing a relationship between the equator and the max temperature.  Both graphs show the max temp. 
# gets higher as the latitude approaches 0. With the Southern Hemisphere it show a positive slope because of the starting x
# value, however the Northern Hemisphere linear regression line has a stronger r- value meaning it has a stronger correlation
# between latitude and the max temperature.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
north_Latitude_df = cleaned_weather_df.loc[cleaned_weather_df['Lat']>=0]
North_Latitude = north_Latitude_df['Lat']
humidity = north_Latitude_df['Humidity']
x_values = North_Latitude
y_values = humidity

# Latitude = cleaned_weather_df['Lat']
# Humidity = cleaned_weather_df['Humidity']
# hum_x_values = Latitude
# hum_y_values = Humidity

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values, y_values, edgecolors='black', color='turquoise')
# plt.title('City Latitde vs. Humidity',  fontweight='bold')
# plt.ylabel('Humidity (%)')
# plt.xlabel('Latitude')
# plt.grid()
# plt.show
# plt.close
# plt.savefig('humidityvslat.png')

# plt.scatter(x_values,y_values,)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(2,4),fontsize=15,color="red")
plt.title('Northern Hemisphere - Latitude vs. Humidity', fontsize=15, fontweight='bold')
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')
print(f"The r-value is: {rvalue}")
print("R-squared: %f" % rvalue**2)
plt.show
plt.close
plt.savefig('N_humidvslat_reg.png')
# Out:
# The r-value is: 0.2668215836228839
# R-squared: 0.071194

# %%
# Out:
# The r-value is: 0.000543987878808455

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Southern Hemisphere (less than 0 degrees latitude)
s_Latitude_df = cleaned_weather_df.loc[cleaned_weather_df['Lat']<0]
S_Latitude = s_Latitude_df['Lat']
humidity = s_Latitude_df['Humidity']
x_values = S_Latitude
y_values = humidity

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values, y_values, edgecolors='turquoise', color='blue')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,20),fontsize=15,color="red")
plt.title('Southern Hemisphere - Latitude vs. Humidity', fontsize=15, fontweight='bold')
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')
print(f"The r-value is: {rvalue}")
print("R-squared: %f" % rvalue**2)
plt.show
plt.close
plt.savefig('s_humidvslat_reg.png')
# Out:
# The r-value is: 0.04192842859073451
# R-squared: 0.001758

# %%
# Out:
# The r-value is: 0.014985174297345524

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
north_Latitude_df = cleaned_weather_df.loc[cleaned_weather_df['Lat']>=0]
North_Latitude = north_Latitude_df['Lat']
Cloudiness = north_Latitude_df['Cloudiness']
x_values = North_Latitude
y_values = Cloudiness

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values, y_values, edgecolors='blue', color='turquoise')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,60),fontsize=15,color="red")
plt.title('Northern Hemisphere - Latitude vs. Cloudiness', fontsize=15, fontweight='bold')
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')
print(f"The r-value is: {rvalue}")
print("R-squared: %f" % rvalue**2)
plt.show
plt.close
plt.savefig('N_cloudvslat_reg.png')
# Out:
# The r-value is: 0.23718702266647418
# R-squared: 0.056258

# %%
# Out:
# The r-value is: 0.0020898727664228514

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
s_Latitude_df = cleaned_weather_df.loc[cleaned_weather_df['Lat']<0]
S_Latitude = s_Latitude_df['Lat']
Cloudiness = s_Latitude_df['Cloudiness']
x_values = S_Latitude
y_values = Cloudiness

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values, y_values, edgecolors='black', color='turquoise')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,30),fontsize=15,color="red")
plt.title('Southern Hemisphere - Latitude vs. Cloudiness', fontsize=15, fontweight='bold')
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')
print(f"The r-value is: {rvalue}")
print("R-squared: %f" % rvalue**2)
plt.show
plt.close
plt.savefig('S_cloudvslat_reg.png')
# Out:
# The r-value is: -0.11888116051270932
# R-squared: 0.014133

# %%
# Out:
# The r-value is: 0.0035263772085582894

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
north_Latitude_df = cleaned_weather_df.loc[cleaned_weather_df['Lat']>=0]
North_Latitude = north_Latitude_df['Lat']
Wind = north_Latitude_df['Wind Speed']
x_values = North_Latitude
y_values = Wind

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values, y_values, edgecolors='blue', color='turquoise')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(10,30),fontsize=15,color="red")
plt.title('Northern Hemisphere - Latitude vs. Wind Speed', fontsize=15, fontweight='bold')
plt.ylabel('Wind Speed (mph)')
plt.xlabel('Latitude')
plt.grid()
print(f"The r-value is: {rvalue}")
print("R-squared: %f" % rvalue**2)
plt.show
plt.close
plt.savefig('N_windvslat_reg.png')
# Out:
# The r-value is: 0.12661447183530142
# R-squared: 0.016031

# %%
# Out:
# The r-value is: 0.04019723576144484

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
s_Latitude_df = cleaned_weather_df.loc[cleaned_weather_df['Lat']<0]
S_Latitude = s_Latitude_df['Lat']
Wind = s_Latitude_df['Wind Speed']
x_values = S_Latitude
y_values = Wind

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values, y_values, edgecolors='purple', color='turquoise')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,23),fontsize=15,color="red")
plt.title('Southern Hemisphere - Latitude vs. Wind Speed', fontsize=15, fontweight='bold')
plt.ylabel('Wind Speed (mph)')
plt.xlabel('Latitude')
plt.grid()
print(f"The r-value is: {rvalue}")
print("R-squared: %f" % rvalue**2)
plt.show
plt.close
plt.savefig('S_windvslat_reg.png')
# Out:
# The r-value is: -0.31893114267430483
# R-squared: 0.101717

# %%
# Out:
# The r-value is: 0.017128274759839232
